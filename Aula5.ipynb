# %% [markdown]
# <a href="https://colab.research.google.com/github/juapgaua/imersaoIA/blob/main/Aula5.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# !pip install -q -U google-generativeai

# %%
# Import the Python SDK
import numpy as np
import pandas as pd
import google.generativeai as genai
from google.colab import userdata
api_key = userdata.get('SECRET_KEY')
genai.configure(api_key=api_key)

# %%
for m in genai.list_models():
  if 'embedContent' in m.supported_generation_methods:
    print(m.name)
# Out:
# models/embedding-001
# models/text-embedding-004

# %%
#Exemplo de embedding
title = 'Seus dados, suas regras: Entendendo a LGPD'
sample_text = ('A Lei Geral de Proteção de Dados (LGPD) chegou para mudar a forma como lidamos com informações pessoais no Brasil.'
'Em vigor desde 2020, a lei garante mais controle, segurança e transparência no uso de seus dados por empresas e órgãos públicos.'
'\n'
'Em resumo, a LGPD define regras claras sobre como seus dados podem ser coletados, armazenados, utilizados e compartilhados.'
'Você tem o direito de saber para que seus dados serão usados, corrigir informações incorretas e até mesmo pedir a exclusão dos seus dados.'
'\n'
'As empresas que desrespeitarem a LGPD podem sofrer sanções, incluindo multas pesadas.'
'Por isso, é fundamental que você esteja atento aos seus direitos e saiba como exercê-los.'
'\n'
'A LGPD é um passo crucial para um futuro digital mais justo e seguro para todos.')

embeddings = genai.embed_content(model='models/embedding-001',
                                 content=sample_text,
                                 title=title,
                                 task_type='RETRIEVAL_DOCUMENT')
print(embeddings)
# Out:
# {'embedding': [0.0069116973, 0.04084279, -0.021167263, 0.053692136, 0.022578448, 0.006556156, -0.020704329, 0.002282552, 0.036650084, 0.053417202, 0.029140087, 0.009162316, -0.0053882855, -0.013248145, 0.023833714, -0.032643538, 0.021863544, -0.010127529, 0.02384341, -0.036786746, 0.0016693239, 0.0032456988, -0.020994877, -0.01935958, -0.043986157, -0.03413302, 0.008741917, -0.045194987, 0.019131185, 0.007772701, 0.007207503, 0.05342322, -0.044604238, 0.023724977, -0.019940807, -0.046536613, -0.022510342, 0.0127218, -0.016015057, 0.028496075, 0.00488434, -0.023787608, -0.03580564, 0.05514211, 0.00845032, 0.013685527, 0.045386378, 0.023376577, -0.03469915, -0.02612728, -0.029377582, 0.014005075, 0.04256955, 0.0013283056, -0.0010662812, -0.01272002, 0.036809962, -0.004536278, -0.010007911, 0.009607105, -0.03608495, 0.024232373, -0.0003447967, 0.038977377, -0.018000117, -0.034103356, -0.02510791, -0.002294467, 0.091093734, -0.02712636, 0.014761445, -0.00516046, 0.014975999, -0.040457383
# ...

# %%
#Listagem de documentos que serão buscados
DOCUMENT1= {
    'Titulo':'O que é a LGPD?',
    'Conteúdo': 'A Lei Geral de Proteção de Dados Pessoais – Lei nº 13.709, de 14 de agosto de 2018, é uma inovação que está em consonância com os regramentos internacionais mais atuais a respeito da proteção de dados. Ela foi criada para regular o tratamento de dados pessoais dos cidadãos, inclusive nos meios digitais, visando proteger seus direitos fundamentais de liberdade e de privacidade e o livre desenvolvimento da personalidade da pessoa natural (pessoa física). Sua aplicação se estende a qualquer pessoa, natural ou jurídica, de direito público ou privado, que realize o tratamento de dados pessoais, online e/ou offline. Esta cartilha apresenta um resumo dos pontos principais da Lei, de modo que a alta administração, servidores e colaboradores conheçam o tema, se engajem na adequação do DNIT à LGPD e, ao mesmo tempo, saibam quais são seus direitos e deveres.'
}

DOCUMENT2= {
    'Titulo':'Fundamentos da Proteção de Dados',
    'Conteúdo':'A LGPD traz claramente quais são os fundamentos relacionados à proteção de dados pessoais, que servem para embasar toda e qualquer ação que envolva seu tratamento. São eles: Inviolabilidade da intimidade, da honra da imagem. Respeito à privacidade. Direitos humanos, livre desenvolvimento da personalidade, dignidade e exercício da cidadania pelas pessoas naturais. Autodeterminação informativa. Livre iniciativa, livre concorrência e defesa do consumidor. Desenvolvimento econômico e tecnológico e inovação.Liberdade de expressão, de informação, de comunicação, e de opinião.A LGPD aprimora o conceito de proteção de dados pessoais, que deve ser realizada de maneira eificiente e eficaz, traduzindo-se em uma forma de estreitar o vínculo com o cidadão, que acredita que suas informações estão seguras e sendo utilizadas de maneira apropriada, obedecendo ao príncipio constitucional da inviolabilidade à privacidade, previsto na Carta Magna, em seu art 5º, inciso X.'
}

DOCUMENT3= {
    'Titulo':'Princípios da LGPD',
    'Conteúdo':'Por fim, é de extrema importância que o tratamento de dados pessoais observe a boa-fé e os 10 princípios elencados na Lei. I - Finalidade: realização do tratamento para propósitos legítimos, específicos, explícitos e informados ao titular, sem possibilidade de tratamento posterior de forma incompatível com essas finalidades; II - Adequação:compatibilidade do tratamento com as finalidades informadas ao titular, de acordo com o contexto do tratamento; III - Necessidade: limitação do tratamento ao mínimo necessário para a realização de suas finalidades, com abrangência dos dados pertinentes, proporcionais e não excessivos em relação às finalidades do tratamento de dados; IV - Livre acesso: garantia, aos titulares, de consulta facilitada e gratuita sobre a forma e a duração do tratamento, bem como sobre a integralidade de seus dados pessoais; V - Qualidade dos dados: garantia, aos titulares, de exatidão, clareza, relevância e atualização dos dados, de acordo com a necessidade e para o cumprimento da finalidade de seu tratamento; VI - Transparência: garantia, aos titulares, de informações claras, precisas e facilmente acessíveis sobre a realização do tratamento e os respectivos agentes de tratamento, observados os segredos comercial e industrial; VII - Segurança: utilização de medidas técnicas e administrativas aptas a proteger os dados pessoais de acessos não autorizados e de situações acidentais ou ilícitas de destruição, perda, alteração, comunicação ou difusão; VIII - Prevenção: adoção de medidas para prevenir a ocorrência de danos em virtude do tratamento de dados pessoais; IX - Não discriminação: impossibilidade de realização do tratamento para fins discriminatórios ilícitos ou abusivos; X - Responsabilização e prestação de contas: demonstração, pelo agente, da adoção de medidas eficazes e capazes de comprovar a observância e o cumprimento das normas de proteção de dados pessoais e, inclusive, da eficácia dessas medidas.'
}
documents = [DOCUMENT1, DOCUMENT2, DOCUMENT3]

# %%
df = pd.DataFrame(documents)
df.columns = ['Titulo', 'Conteudo']
df
# Out:
#                              Titulo  \
# 0                   O que é a LGPD?
# 1  Fundamentos da Proteção de Dados
# 2                Princípios da LGPD
#
#                                             Conteudo
# 0  A Lei Geral de Proteção de Dados Pessoais – Le...
# 1  A LGPD traz claramente quais são os fundamento...
# 2  Por fim, é de extrema importância que o tratam...

# %%
model = "models/embedding-001"

# %%
def embed_fd(title, text):
  return genai.embed_content(model=model,
                                 content=text,
                                 title=title,
                                 task_type='RETRIEVAL_DOCUMENT')['embedding']

# %%
#cria uma nova coluna: lambda cria um tipo um for que pega uma linha de cada vez, quebrada em 2 variaveis - argumentos posicionais - seguir a mesma sequencia / axis=1 é o eixo
df['Embeddings'] = df.apply(lambda row: embed_fd(row['Titulo'], row['Conteudo']), axis=1)
df
# Out:
#                              Titulo  \
# 0                   O que é a LGPD?
# 1  Fundamentos da Proteção de Dados
# 2                Princípios da LGPD
#
#                                             Conteudo  \
# 0  A Lei Geral de Proteção de Dados Pessoais – Le...
# 1  A LGPD traz claramente quais são os fundamento...
# 2  Por fim, é de extrema importância que o tratam...
#
#                                           Embeddings
# 0  [0.0137271965, 0.033537105, -0.033910096, 0.02...
# 1  [0.020396296, 0.019294346, -0.032154724, 0.030...
# 2  [0.050673347, 0.007170492, -0.02873909, 0.0278...

# %%
def gerar_e_buscar_consulta(consulta, base, model):
  embedding_da_consulta = genai.embed_content(model=model,
                                 content=consulta,
                                 task_type='RETRIEVAL_QUERY')['embedding']

  produtos_escalares = np.dot(np.stack(df['Embeddings']), embedding_da_consulta)

  indice = np.argmax(produtos_escalares)
  return df.iloc[indice]['Conteudo']

# %%
consulta = 'Como deve ser uma política de privacidade?'

trecho = gerar_e_buscar_consulta(consulta, df, model)
print(trecho)
# Out:
# A LGPD traz claramente quais são os fundamentos relacionados à proteção de dados pessoais, que servem para embasar toda e qualquer ação que envolva seu tratamento. São eles: Inviolabilidade da intimidade, da honra da imagem. Respeito à privacidade. Direitos humanos, livre desenvolvimento da personalidade, dignidade e exercício da cidadania pelas pessoas naturais. Autodeterminação informativa. Livre iniciativa, livre concorrência e defesa do consumidor. Desenvolvimento econômico e tecnológico e inovação.Liberdade de expressão, de informação, de comunicação, e de opinião.A LGPD aprimora o conceito de proteção de dados pessoais, que deve ser realizada de maneira eificiente e eficaz, traduzindo-se em uma forma de estreitar o vínculo com o cidadão, que acredita que suas informações estão seguras e sendo utilizadas de maneira apropriada, obedecendo ao príncipio constitucional da inviolabilidade à privacidade, previsto na Carta Magna, em seu art 5º, inciso X.

# %%
generation_config = {
    'temperature': 0.5,
    'candidate_count': 1,
}

# %%
prompt = f'Reescreva esse texto de uma forma mais descontraida, sem adicionar informações que não façam parte do texto: {trecho}'

model_2 = genai.GenerativeModel("gemini-1.0-pro",
                                generation_config=generation_config)
response = model_2.generate_content(prompt)
print(response.text)
# Out:
# **A LGPD na pegada "good vibes only"**
#
# A LGPD é tipo uma cartilha que mostra como proteger seus dados pessoais com estilo. É pra garantir que ninguém vai dar uma de "bisbilhoteiro" ou usar suas informações pra te dar um "trote".
#
# Aqui estão os "mandamentos" da LGPD:
#
# * Respeita sua privacidade, tá ligado?
# * Protege sua honra e imagem, tipo um "escudo" pra sua reputação.
# * Defende seus direitos humanos, pra você se sentir "livre como um pássaro".
# * Te dá o poder de controlar suas informações, tipo um "superpoder".
# * Garante que as empresas não vão fazer "joguinhos" com seus dados.
# * Apoia o desenvolvimento tecnológico, mas sempre com responsabilidade.
# * Defende a liberdade de expressão, pra você falar o que pensa sem medo.
#
# A LGPD é tipo um "abraço virtual" pra você, mostrando que suas informações estão seguras e sendo usadas do jeito certo. É como aquele amigo que te dá um "toca aqui" e fala: "Pode confiar, tô cuidando de você!"
